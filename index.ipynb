# %% [markdown]
# # Dealing with Categorical Variables - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, you'll explore the Ames Housing dataset and identify numeric and categorical variables. Then you'll transform some categorical data and use it in a multiple regression model.

# %% [markdown]
# ## Objectives
#
# You will be able to:
#
# * Determine whether variables are categorical or numeric
# * Use one-hot encoding to create dummy variables

# %% [markdown]
# ## Step 1: Load the Ames Housing Dataset
#
# Import `pandas`, and use it to load the file `ames.csv` into a dataframe called `ames`. If you pass in the argument `index_col=0` this will set the "Id" feature as the index.

# %%
# Your code here - load the dataset
import pandas as pd
ames = pd.read_csv("./ames.csv", index_col=0)
ames.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# Visually inspect `ames` (it's ok if you can't see all of the columns).

# %%
# Your code here
ames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# Go ahead and drop all **columns** with missing data, to simplify the problem. Remember that you can use the `dropna` method ([documentation here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html)).

# %%
ames.isna().sum()
# Out:
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 80, dtype: int64

# %%
# Your code here - drop columns with missing data
ames_clean = ames.dropna(axis=1)
ames_clean.head()
# Out:
#     MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# Id
# 1           60       RL     8450   Pave      Reg         Lvl    AllPub
# 2           20       RL     9600   Pave      Reg         Lvl    AllPub
# 3           60       RL    11250   Pave      IR1         Lvl    AllPub
# 4           70       RL     9550   Pave      IR1         Lvl    AllPub
# 5           60       RL    14260   Pave      IR1         Lvl    AllPub
#
#    LotConfig LandSlope Neighborhood  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# Id                                   ...
# 1     Inside       Gtl      CollgCr  ...             0         0           0
# 2        FR2       Gtl      Veenker  ...             0         0           0
# 3     Inside       Gtl      CollgCr  ...             0         0           0
# 4     Corner       Gtl      Crawfor  ...           272         0           0
# 5        FR2       Gtl      NoRidge  ...             0         0           0
#
# ...

# %% [markdown]
# ## Step 2: Identify Numeric and Categorical Variables
#
# The file `data_description.txt`, located in this repository, has a full description of all variables.
#
# Using this file as well as `pandas` techniques, identify the following predictors:
#
# 1. A **continuous numeric** predictor
# 2. A **discrete numeric** predictor
# 3. A **string categorical** predictor
# 4. A **discrete categorical** predictor
#
# (Note that `SalePrice` is the target variable and should not be selected as a predictor.)
#
# For each of these predictors, visualize the relationship between the predictor and `SalePrice` using an appropriate plot.
#
# Finding these will take some digging -- don't be discouraged if they're not immediately obvious. The Ames Housing dataset is a lot more complex than the Auto MPG dataset. There is also no single right answer here.

# %% [markdown]
# ### Continuous Numeric Predictor

# %%
# we have 34 int and 27 strings 
ames_clean.dtypes.value_counts()
# Out:
# int64     34
# object    27
# dtype: int64

# %%
# numeric columns
ames_clean.describe()
# Out:
#         MSSubClass        LotArea  OverallQual  OverallCond    YearBuilt  \
# count  1460.000000    1460.000000  1460.000000  1460.000000  1460.000000
# mean     56.897260   10516.828082     6.099315     5.575342  1971.267808
# std      42.300571    9981.264932     1.382997     1.112799    30.202904
# min      20.000000    1300.000000     1.000000     1.000000  1872.000000
# 25%      20.000000    7553.500000     5.000000     5.000000  1954.000000
# 50%      50.000000    9478.500000     6.000000     5.000000  1973.000000
# 75%      70.000000   11601.500000     7.000000     6.000000  2000.000000
# max     190.000000  215245.000000    10.000000     9.000000  2010.000000
#
#        YearRemodAdd   BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  TotalBsmtSF  ...  \
# count   1460.000000  1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean    1984.865753   443.639726    46.549315   567.240411  1057.429452  ...
# std       20.645407   456.098091   161.319273   441.866955   438.705324  ...
# ...

# %%
ames_clean.select_dtypes(include='object').nunique().sort_values()
# Out:
# Street            2
# Utilities         2
# CentralAir        2
# LandSlope         3
# PavedDrive        3
# LotShape          4
# LandContour       4
# KitchenQual       4
# ExterQual         4
# MSZoning          5
# LotConfig         5
# BldgType          5
# HeatingQC         5
# ExterCond         5
# Heating           6
# Foundation        6
# SaleCondition     6
# RoofStyle         6
# Functional        7
# HouseStyle        8
# Condition2        8
# RoofMatl          8
# SaleType          9
# Condition1        9
# Exterior1st      15
# Exterior2nd      16
# Neighborhood     25
# dtype: int64

# %%
# Your code here - continuous numeric predictor
numeric_cols = ames_clean.select_dtypes(include='number').columns.tolist()
numeric_cols = [col for col in numeric_cols if col != 'SalePrice']
continuous_numeric = [col for col in numeric_cols if ames_clean[col].nunique() > 15]
print(continuous_numeric)
# Out:
# ['LotArea', 'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'MiscVal']

# %% [markdown]
# ### Discrete Numeric Predictor

# %%
# Your code here - discrete numeric predictor
discrete_numeric = [col for col in numeric_cols if ames_clean[col].nunique() <= 15]
print(discrete_numeric)
# Out:
# ['MSSubClass', 'OverallQual', 'OverallCond', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'PoolArea', 'MoSold', 'YrSold']

# %% [markdown]
# ### String Categorical Predictor

# %%
# Your code here - string categorical predictor
string_categorical = ames_clean.select_dtypes(include='object').columns.tolist()
print(string_categorical)
# Out:
# ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'Heating', 'HeatingQC', 'CentralAir', 'KitchenQual', 'Functional', 'PavedDrive', 'SaleType', 'SaleCondition']

# %% [markdown]
# ### Discrete Categorical Predictor

# %%
# Your code here - discrete categorical predictor
discrete_categorical = [col for col in numeric_cols if ames_clean[col].nunique() <= 15]
print(discrete_categorical)
# Out:
# ['MSSubClass', 'OverallQual', 'OverallCond', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'PoolArea', 'MoSold', 'YrSold']

# %% [markdown]
# ## Step 3: Build a Multiple Regression Model with Your Chosen Predictors
#
# Choose the best-looking 3 out of 4 predictors to include in your model.
#
# Make sure that you one-hot encode your categorical predictor(s) (regardless of whether the current data type is a string or number) first.

# %%
X2.dtypes
# Out:
# const             float64
# MSSubClass          int64
# MSZoning           object
# LotArea             int64
# Street             object
#                    ...
# OverallQual_6       int32
# OverallQual_7       int32
# OverallQual_8       int32
# OverallQual_9       int32
# OverallQual_10      int32
# Length: 69, dtype: object

# %%
# There are too many categorical columns in our housing data set so we encode all of them
categorical_cols = ames_clean.select_dtypes(include=['object', 'category']).columns
print(categorical_cols)
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'Heating',
#        'HeatingQC', 'CentralAir', 'KitchenQual', 'Functional', 'PavedDrive',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
# Your code here - prepare X and y, including one-hot encoding
ames_dummies = pd.get_dummies(ames_clean, columns=categorical_cols ,drop_first=True, dtype=int)


X2 = ames_dummies.drop(columns=['SalePrice'])
y = ames_dummies['SalePrice']

ames_dummies.head()
# Out:
#     MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# Id
# 1           60     8450            7            5       2003          2003
# 2           20     9600            6            8       1976          1976
# 3           60    11250            7            5       2001          2002
# 4           70     9550            7            5       1915          1970
# 5           60    14260            8            5       2000          2000
#
#     BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ...  SaleType_ConLI  \
# Id                                                  ...
# 1          706           0        150          856  ...               0
# 2          978           0        284         1262  ...               0
# 3          486           0        434          920  ...               0
# 4          216           0        540          756  ...               0
# 5          655           0        490         1145  ...               0
#
# ...

# %%
# Your answer here - which category or categories were dropped?
# the category that was dropped is OverallQual 1

# %%
# Your code here - build a regression model and display results
import statsmodels.api as sm
X2 = sm.add_constant(X2)
model2 = sm.OLS(y, X2).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.909
# Method:                 Least Squares   F-statistic:                     79.79
# Date:                Sun, 30 Nov 2025   Prob (F-statistic):               0.00
# Time:                        16:04:31   Log-Likelihood:                -16695.
# No. Observations:                1460   AIC:                         3.376e+04
# Df Residuals:                    1274   BIC:                         3.475e+04
# Df Model:                         185
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Step 4: Create Partial Regression Plots for Features
#
# For each feature of the regression above (including the dummy features), plot the partial regression.

# %%
# Your code here - create partial regression plots
import matplotlib.pyplot as plt


# Plot partial regression for all features in the model
fig = plt.figure(figsize=(12, 8))
sm.graphics.plot_partregress_grid(model2, fig=fig)
plt.tight_layout()
plt.show()
# Out:
# c:\Users\hp\anaconda3\envs\learn-env\lib\site-packages\statsmodels\graphics\regressionplots.py:561: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   fig.tight_layout()
# <ipython-input-84-96a4a477e0fe>:8: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations
#   plt.tight_layout()

# %% [markdown]
# ## Step 5: Calculate an Error-Based Metric
#
# In addition to the adjusted R-Squared that we can see in the model summary, calculate either MAE or RMSE for this model.

# %%
# Your code here - calculate an error-based metric

# %% [markdown]
# ## Step 6: Summarize Findings
#
# Between the model results, partial regression plots, and error-based metric, what does this model tell you? What would your next steps be to improve the model?

# %%
# Your answer here

# %% [markdown]
# ## Level Up (Optional)
#
# Try transforming X using scikit-learn _and_ fitting a scikit-learn linear regression as well. If there are any differences in the result, investigate them.

# %%
# Your code here

# %% [markdown]
# ## Summary
#
# In this lab, you practiced your knowledge of categorical variables on the Ames Housing dataset! Specifically, you practiced distinguishing numeric and categorical data. You then created dummy variables using one hot encoding in order to build a multiple regression model.
